# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

import tensorflow_decision_forests as tfdf

# %% [markdown]
# ## Read Input CSV

# %%
df = pd.read_csv("data/train.csv")

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# Remove columns that aren't useful, and fill NaN values:

# %%
try:
    df = df.drop(["PassengerId", "Name"], axis=1)
except KeyError:
    print("Field already dropped")

for c in ("VIP", "CryoSleep", "FoodCourt", "ShoppingMall", "Spa", "VRDeck"):
    df[c].fillna(value=0, inplace=True)

df.isnull().sum().sort_values(ascending=False)
# Out:
# HomePlanet      201
# Cabin           199
# Destination     182
# RoomService     181
# Age             179
# CryoSleep         0
# VIP               0
# FoodCourt         0
# ShoppingMall      0
# Spa               0
# VRDeck            0
# Transported       0
# dtype: int64

# %% [markdown]
# Change boolean to integer becuase TF-DF focuses on numerical and categorical features:

# %%
LABEL = "Transported"

df[LABEL] = df[LABEL].astype(int)
df["VIP"] = df["VIP"].astype(int)
df["CryoSleep"] = df["CryoSleep"].astype(int)

df["Cabin"] = df["Cabin"].apply(
    lambda x: x[0] + x[-1] if pd.notnull(x) and x != "" else x
)

# %%
df.head()
# Out:
#   HomePlanet  CryoSleep Cabin  Destination   Age  VIP  RoomService  FoodCourt  \
# 0     Europa          0    BP  TRAPPIST-1e  39.0    0          0.0        0.0
# 1      Earth          0    FS  TRAPPIST-1e  24.0    0        109.0        9.0
# 2     Europa          0    AS  TRAPPIST-1e  58.0    1         43.0     3576.0
# 3     Europa          0    AS  TRAPPIST-1e  33.0    0          0.0     1283.0
# 4      Earth          0    FS  TRAPPIST-1e  16.0    0        303.0       70.0
#
#    ShoppingMall     Spa  VRDeck  Transported
# 0           0.0     0.0     0.0            0
# 1          25.0   549.0    44.0            1
# 2           0.0  6715.0    49.0            0
# 3         371.0  3329.0   193.0            0
# 4         151.0   565.0     2.0            1

# %% [markdown]
# ## Train/Validation Split

# %%
train_df, val_df = train_test_split(df, test_size=0.2, random_state=42)
train_df.shape
# Out:
# (6954, 12)

# %% [markdown]
# ## PD-DF 2 TF-DS

# %%
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(train_df, label=LABEL)
valid_ds = tfdf.keras.pd_dataframe_to_tf_dataset(val_df, label=LABEL)

# %% [markdown]
# ## Automated Hyper-Parameter Tuning

# %%
# tuner = tfdf.tuner.RandomSearch(num_trials=50)
# local_search_space = tuner.choice("growing_strategy", ["LOCAL"])
# local_search_space.choice("max_depth", [5, 8, 10, 13])
# global_search_space = tuner.choice(
#     "growing_strategy", ["BEST_FIRST_GLOBAL"], merge=True
# )
# global_search_space.choice("max_num_nodes", [25, 50, 100, 150, 200])
# tuned_model = tfdf.keras.RandomForestModel(tuner=tuner)
# tuned_model.fit(train_ds, verbose=2)

# %%
# automatic definition of the hyper-parameters
# Set use_predefined_hps=True to automatically configure the search space for the hyper-parameters.

tuner = tfdf.tuner.RandomSearch(num_trials=50, use_predefined_hps=True)
tuned_model = tfdf.keras.RandomForestModel(tuner=tuner)
tuned_model.fit(train_ds, verbose=2)
# Out:
# Use /var/folders/2j/5hwf_xns24z3hc6bmf268x340000gn/T/tmporblgvqk as temporary training directory
# Reading training dataset...
# Training tensor examples:
# Features: {'HomePlanet': <tf.Tensor 'data:0' shape=(None,) dtype=string>, 'CryoSleep': <tf.Tensor 'data_1:0' shape=(None,) dtype=int64>, 'Cabin': <tf.Tensor 'data_2:0' shape=(None,) dtype=string>, 'Destination': <tf.Tensor 'data_3:0' shape=(None,) dtype=string>, 'Age': <tf.Tensor 'data_4:0' shape=(None,) dtype=float64>, 'VIP': <tf.Tensor 'data_5:0' shape=(None,) dtype=int64>, 'RoomService': <tf.Tensor 'data_6:0' shape=(None,) dtype=float64>, 'FoodCourt': <tf.Tensor 'data_7:0' shape=(None,) dtype=float64>, 'ShoppingMall': <tf.Tensor 'data_8:0' shape=(None,) dtype=float64>, 'Spa': <tf.Tensor 'data_9:0' shape=(None,) dtype=float64>, 'VRDeck': <tf.Tensor 'data_10:0' shape=(None,) dtype=float64>}
# Label: Tensor("data_11:0", shape=(None,), dtype=int64)
# Weights: None
# Normalized tensor features:
#  {'HomePlanet': SemanticTensor(semantic=<Semantic.CATEGORICAL: 2>, tensor=<tf.Tensor 'data:0' shape=(None,) dtype=string>), 'CryoSleep': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast:0' shape=(None,) dtype=float32>), 'Cabin': SemanticTensor(semantic=<Semantic.CATEGORICAL: 2>, tensor=<tf.Tensor 'data_2:0' shape=(None,) dtype=string>), 'Destination': SemanticTensor(semantic=<Semantic.CATEGORICAL: 2>, tensor=<tf.Tensor 'data_3:0' shape=(None,) dtype=string>), 'Age': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_1:0' shape=(None,) dtype=float32>), 'VIP': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_2:0' shape=(None,) dtype=float32>), 'RoomService': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_3:0' shape=(None,) dtype=float32>), 'FoodCourt': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_4:0' shape=(None,) dtype=float32>), 'ShoppingMall': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_5:0' shape=(None,) dtype=float32>), 'Spa': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_6:0' shape=(None,) dtype=float32>), 'VRDeck': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_7:0' shape=(None,) dtype=float32>)}
# Training dataset read in 0:00:01.505108. Found 6954 examples.
# Training model...
# Standard output detected as not visible to the user e.g. running in a notebook. Creating a training log redirection. If training gets stuck, try calling tfdf.keras.set_training_logs_redirection(False).
# [INFO 23-11-24 10:44:46.1284 CST kernel.cc:771] Start Yggdrasil model training
# [INFO 23-11-24 10:44:46.1290 CST kernel.cc:772] Collect training examples
# [INFO 23-11-24 10:44:46.1290 CST kernel.cc:785] Dataspec guide:
# column_guides {
#   column_name_pattern: "^__LABEL$"
#   type: CATEGORICAL
#   categorial {
#     min_vocab_frequency: 0
#     max_vocab_count: -1
#   }
# }
# default_column_guide {
#   categorial {
#     max_vocab_count: 2000
#   }
#   discretized_numerical {
#     maximum_num_bins: 255
#   }
# }
# ignore_columns_without_guides: false
# detect_numerical_as_discretized_numerical: false
#
# [INFO 23-11-24 10:44:46.1292 CST kernel.cc:391] Number of batches: 7
# [INFO 23-11-24 10:44:46.1292 CST kernel.cc:392] Number of examples: 6954
# [INFO 23-11-24 10:44:46.1301 CST data_spec_inference.cc:305] 2 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Cabin (14 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# [INFO 23-11-24 10:44:46.1305 CST kernel.cc:792] Training dataset:
# Number of records: 6954
# Number of columns: 12
#
# Number of columns by type:
# 	NUMERICAL: 8 (66.6667%)
# 	CATEGORICAL: 4 (33.3333%)
#
# Columns:
#
# NUMERICAL: 8 (66.6667%)
# 	0: "Age" NUMERICAL num-nas:148 (2.12827%) mean:28.8281 min:0 max:79 sd:14.4453
# 	2: "CryoSleep" NUMERICAL mean:0.345125 min:0 max:1 sd:0.475409
# 	4: "FoodCourt" NUMERICAL mean:447.52 min:0 max:27723 sd:1560.07
# 	6: "RoomService" NUMERICAL num-nas:126 (1.81191%) mean:222.823 min:0 max:14327 sd:674.851
# 	7: "ShoppingMall" NUMERICAL mean:171.335 min:0 max:23492 sd:607.185
# 	8: "Spa" NUMERICAL mean:309.611 min:0 max:18572 sd:1108.02
# 	9: "VIP" NUMERICAL mean:0.0224331 min:0 max:1 sd:0.148087
# 	10: "VRDeck" NUMERICAL mean:297.585 min:0 max:24133 sd:1158.62
#
# CATEGORICAL: 4 (33.3333%)
# 	1: "Cabin" CATEGORICAL num-nas:158 (2.27207%) has-dict vocab-size:15 num-oods:5 (0.0735727%) most-frequent:"FP" 1158 (17.0394%)
# 	3: "Destination" CATEGORICAL num-nas:139 (1.99885%) has-dict vocab-size:4 zero-ood-items most-frequent:"TRAPPIST-1e" 4733 (69.4497%)
# 	5: "HomePlanet" CATEGORICAL num-nas:168 (2.41588%) has-dict vocab-size:4 zero-ood-items most-frequent:"Earth" 3691 (54.3914%)
# 	11: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# [INFO 23-11-24 10:44:46.1305 CST kernel.cc:808] Configure learner
# [INFO 23-11-24 10:44:46.1307 CST kernel.cc:822] Training config:
# learner: "HYPERPARAMETER_OPTIMIZER"
# features: "^Age$"
# features: "^Cabin$"
# features: "^CryoSleep$"
# features: "^Destination$"
# features: "^FoodCourt$"
# features: "^HomePlanet$"
# features: "^RoomService$"
# features: "^ShoppingMall$"
# features: "^Spa$"
# features: "^VIP$"
# features: "^VRDeck$"
# label: "^__LABEL$"
# task: CLASSIFICATION
# metadata {
#   framework: "TF Keras"
# }
# [yggdrasil_decision_forests.model.hyperparameters_optimizer_v2.proto.hyperparameters_optimizer_config] {
#   base_learner {
#     learner: "RANDOM_FOREST"
#     features: "^Age$"
#     features: "^Cabin$"
#     features: "^CryoSleep$"
#     features: "^Destination$"
#     features: "^FoodCourt$"
#     features: "^HomePlanet$"
#     features: "^RoomService$"
#     features: "^ShoppingMall$"
#     features: "^Spa$"
#     features: "^VIP$"
#     features: "^VRDeck$"
#     label: "^__LABEL$"
#     task: CLASSIFICATION
#     random_seed: 123456
#     pure_serving_model: false
#     [yggdrasil_decision_forests.model.random_forest.proto.random_forest_config] {
#       num_trees: 300
#       decision_tree {
#         max_depth: 16
#         min_examples: 5
#         in_split_min_examples_check: true
#         keep_non_leaf_label_distribution: true
#         num_candidate_attributes: 0
#         missing_value_policy: GLOBAL_IMPUTATION
#         allow_na_conditions: false
#         categorical_set_greedy_forward {
#           sampling: 0.1
#           max_num_items: -1
#           min_item_frequency: 1
#         }
#         growing_strategy_local {
#         }
#         categorical {
#           cart {
#           }
#         }
#         axis_aligned_split {
#         }
#         internal {
#           sorting_strategy: PRESORTED
#         }
#         uplift {
#           min_examples_in_treatment: 5
#           split_score: KULLBACK_LEIBLER
#         }
#       }
#       winner_take_all_inference: true
#       compute_oob_performances: true
#       compute_oob_variable_importances: false
#       num_oob_variable_importances_permutations: 1
#       bootstrap_training_dataset: true
#       bootstrap_size_ratio: 1
#       adapt_bootstrap_size_ratio_for_maximum_training_duration: false
#       sampling_with_replacement: true
#     }
#   }
#   optimizer {
#     optimizer_key: "RANDOM"
#     [yggdrasil_decision_forests.model.hyperparameters_optimizer_v2.proto.random] {
#       num_trials: 50
#     }
#   }
#   base_learner_deployment {
#     num_threads: 1
#   }
#   predefined_search_space {
#   }
# }
#
# [INFO 23-11-24 10:44:46.1309 CST kernel.cc:825] Deployment config:
# cache_path: "/var/folders/2j/5hwf_xns24z3hc6bmf268x340000gn/T/tmporblgvqk/working_cache"
# num_threads: 10
# try_resume_training: true
#
# [INFO 23-11-24 10:44:46.1310 CST kernel.cc:887] Train model
# [INFO 23-11-24 10:44:46.1311 CST hyperparameters_optimizer.cc:209] Hyperparameter search space:
# fields {
#   name: "split_axis"
#   discrete_candidates {
#     possible_values {
#       categorical: "AXIS_ALIGNED"
#     }
#     possible_values {
#       categorical: "SPARSE_OBLIQUE"
#     }
#   }
#   children {
#     name: "sparse_oblique_projection_density_factor"
#     discrete_candidates {
#       possible_values {
#         real: 1
#       }
#       possible_values {
#         real: 2
#       }
#       possible_values {
#         real: 3
#       }
#       possible_values {
#         real: 4
#       }
#       possible_values {
#         real: 5
#       }
#     }
#     parent_discrete_values {
#       possible_values {
#         categorical: "SPARSE_OBLIQUE"
#       }
#     }
#   }
#   children {
#     name: "sparse_oblique_normalization"
#     discrete_candidates {
#       possible_values {
#         categorical: "NONE"
#       }
#       possible_values {
#         categorical: "STANDARD_DEVIATION"
#       }
#       possible_values {
#         categorical: "MIN_MAX"
#       }
#     }
#     parent_discrete_values {
#       possible_values {
#         categorical: "SPARSE_OBLIQUE"
#       }
#     }
#   }
#   children {
#     name: "sparse_oblique_weights"
#     discrete_candidates {
#       possible_values {
#         categorical: "BINARY"
#       }
#       possible_values {
#         categorical: "CONTINUOUS"
#       }
#     }
#     parent_discrete_values {
#       possible_values {
#         categorical: "SPARSE_OBLIQUE"
#       }
#     }
#   }
# }
# fields {
#   name: "categorical_algorithm"
#   discrete_candidates {
#     possible_values {
#       categorical: "CART"
#     }
#     possible_values {
#       categorical: "RANDOM"
#     }
#   }
# }
# fields {
#   name: "winner_take_all"
#   discrete_candidates {
#     possible_values {
#       categorical: "true"
#     }
#   }
# }
# fields {
#   name: "max_depth"
#   discrete_candidates {
#     possible_values {
#       integer: 12
#     }
#     possible_values {
#       integer: 16
#     }
#     possible_values {
#       integer: 20
#     }
#     possible_values {
#       integer: 25
#     }
#     possible_values {
#       integer: 30
#     }
#   }
# }
# fields {
#   name: "min_examples"
#   discrete_candidates {
#     possible_values {
#       integer: 1
#     }
#     possible_values {
#       integer: 2
#     }
#     possible_values {
#       integer: 5
#     }
#     possible_values {
#       integer: 10
#     }
#     possible_values {
#       integer: 40
#     }
#   }
# }
#
# [INFO 23-11-24 10:44:46.1312 CST hyperparameters_optimizer.cc:500] Start local tuner with 10 thread(s)
# [INFO[INFO[INFO 23-11-24 10:44:46.1315 CST random_forest.cc:[INFO416] Training random forest on 6954 example(s) and 11 feature(s).
#  23-11-24 10:44:46.1315 CST random_forest.cc:416] Training random forest on 6954 example(s) and 11 feature(s).
CST random_forest.cc:416] Training random forest on 6954 example(s) and 11 feature(s).
#  23-11-24 10:45:17.2241 CST hyperparameters_optimizer.cc:582] [2/50] Score: 0.803279 / 0.803423 HParams: fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_projection_density_factor" value { real: 1 } } fields { name: "sparse_oblique_normalization" value { categorical: "MIN_MAX" } } fields { name: "sparse_oblique_weights" value { categorical: "CONTINUOUS" } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "winner_take_all" value { categorical: "true" } } fields { name: "max_depth" value { integer: 20 } } fields { name: "min_examples" value { integer: 10 } }
# [INFO 23-11-24 10:45:17.4008 CST random_forest.cc:802] Training of tree  1/300 (tree index:0) done accuracy:0.738329 logloss:9.43159
# [INFO 23-11-24 10:45:17.5250 CST random_forest.cc:802] Training of tree  231/300 (tree index:230) done accuracy:0.803279 logloss:0.629548
# [INFO 23-11-24 10:45:17.5970 CST random_forest.cc:802] Training of tree  141/300 (tree index:140) done accuracy:0.801122 logloss:0.753701
# [INFO 23-11-24 10:45:18.1682 CST random_forest.cc:802] Training of tree  161/300 (tree index:160) done accuracy:0.794219 logloss:0.675086
# [INFO 23-11-24 10:45:18.5781 CST random_forest.cc:802] Training of tree  31/300 (tree index:30) done accuracy:0.79537 logloss:1.74369
# [INFO 23-11-24 10:45:18.6413 CST random_forest.cc:802] Training of tree  191/300 (tree index:190) done accuracy:0.803566 logloss:1.03448
# [INFO 23-11-24 10:45:18.7477 CST random_forest.cc:802] Training of tree  141/300 (tree index:140) done accuracy:0.797958 logloss:0.669153
# [INFO 23-11-24 10:45:18.8315 CST random_forest.cc:802] Training of tree  241/300 (tree index:240) done accuracy:0.805148 logloss:0.616067
# [INFO 23-11-24 10:45:18.8362 CST random_forest.cc:802] Training of tree  151/300 (tree index:150) done accuracy:0.804429 logloss:0.668054
# [INFO 23-11-24 10:45:19.0541 CST random_forest.cc:802] Training of tree  171/300 (tree index:170) done accuracy:0.801409 logloss:0.661113
# [INFO 23-11-24 10:45:19.2386 CST random_forest.cc:802] Training of tree  151/300 (tree index:150) done accuracy:0.791918 logloss:0.699248
# [INFO 23-11-24 10:45:19.3456 CST random_forest.cc:802] Training of tree  11/300 (tree index:10) done accuracy:0.768118 logloss:3.66213
# [INFO 23-11-24 10:45:19.7375 CST random_forest.cc:802] Training of tree  151/300 (tree index:150) done accuracy:0.800834 logloss:0.730314
# [INFO 23-11-24 10:45:20.0950 CST random_forest.cc:802] Training of tree  171/300 (tree index:170) done accuracy:0.794363 logloss:0.66644
# [INFO 23-11-24 10:45:20.1917 CST random_forest.cc:802] Training of tree  251/300 (tree index:250) done accuracy:0.804861 logloss:0.616387
# [INFO 23-11-24 10:45:20.3428 CST random_forest.cc:802] Training of tree  201/300 (tree index:200) done accuracy:0.803566 logloss:1.03098
# [INFO 23-11-24 10:45:20.4539 CST random_forest.cc:802] Training of tree  41/300 (tree index:40) done accuracy:0.799108 logloss:1.39076
# [INFO 23-11-24 10:45:20.8968 CST random_forest.cc:802] Training of tree  181/300 (tree index:180) done accuracy:0.802272 logloss:0.637724
# [INFO 23-11-24 10:45:20.9878 CST random_forest.cc:802] Training of tree  151/300 (tree index:150) done accuracy:0.795513 logloss:0.664179
# [INFO 23-11-24 10:45:21.0539 CST random_forest.cc:802] Training of tree  161/300 (tree index:160) done accuracy:0.803135 logloss:0.658593
# [INFO 23-11-24 10:45:21.3341 CST random_forest.cc:802] Training of tree  21/300 (tree index:20) done accuracy:0.777682 logloss:2.13365
# [INFO 23-11-24 10:45:21.4504 CST random_forest.cc:802] Training of tree  261/300 (tree index:260) done accuracy:0.805436 logloss:0.616072
# [INFO 23-11-24 10:45:21.4971 CST random_forest.cc:802] Training of tree  161/300 (tree index:160) done accuracy:0.791918 logloss:0.698139
# [INFO 23-11-24 10:45:21.9349 CST random_forest.cc:802] Training of tree  161/300 (tree index:160) done accuracy:0.799971 logloss:0.717441
# [INFO 23-11-24 10:45:21.9979 CST random_forest.cc:802] Training of tree  211/300 (tree index:210) done accuracy:0.803135 logloss:1.00788
# [INFO 23-11-24 10:45:22.0673 CST random_forest.cc:802] Training of tree  181/300 (tree index:180) done accuracy:0.794938 logloss:0.661462
# [INFO 23-11-24 10:45:22.4421 CST random_forest.cc:802] Training of tree  51/300 (tree index:50) done accuracy:0.804142 logloss:1.24711
# [INFO 23-11-24 10:45:22.7402 CST random_forest.cc:802] Training of tree  271/300 (tree index:270) done accuracy:0.805004 logloss:0.61136
# [INFO 23-11-24 10:45:22.7595 CST random_forest.cc:802] Training of tree  191/300 (tree index:190) done accuracy:0.804429 logloss:0.632918
# [INFO 23-11-24 10:45:23.1235 CST random_forest.cc:802] Training of tree  171/300 (tree index:170) done accuracy:0.803998 logloss:0.639175
# [INFO 23-11-24 10:45:23.1735 CST random_forest.cc:802] Training of tree  161/300 (tree index:160) done accuracy:0.79767 logloss:0.663846
# [INFO 23-11-24 10:45:23.2940 CST random_forest.cc:802] Training of tree  31/300 (tree index:30) done accuracy:0.780702 logloss:1.61777
# [INFO 23-11-24 10:45:23.6142 CST random_forest.cc:802] Training of tree  171/300 (tree index:170) done accuracy:0.793069 logloss:0.684812
# [INFO 23-11-24 10:45:23.7598 CST random_forest.cc:802] Training of tree  221/300 (tree index:220) done accuracy:0.803566 logloss:0.988196
# [INFO 23-11-24 10:45:24.0472 CST random_forest.cc:802] Training of tree  171/300 (tree index:170) done accuracy:0.800546 logloss:0.712785
# [INFO 23-11-24 10:45:24.0821 CST random_forest.cc:802] Training of tree  191/300 (tree index:190) done accuracy:0.793788 logloss:0.656149
# [INFO 23-11-24 10:45:24.0918 CST random_forest.cc:802] Training of tree  281/300 (tree index:280) done accuracy:0.805148 logloss:0.61149
# [INFO 23-11-24 10:45:24.3289 CST random_forest.cc:802] Training of tree  61/300 (tree index:60) done accuracy:0.80371 logloss:1.10958
# [INFO 23-11-24 10:45:24.6046 CST random_forest.cc:802] Training of tree  201/300 (tree index:200) done accuracy:0.802847 logloss:0.623411
# [INFO 23-11-24 10:45:25.1071 CST random_forest.cc:802] Training of tree  181/300 (tree index:180) done accuracy:0.802991 logloss:0.625978
# [INFO 23-11-24 10:45:25.2458 CST random_forest.cc:802] Training of tree  41/300 (tree index:40) done accuracy:0.784009 logloss:1.37651
# [INFO 23-11-24 10:45:25.3983 CST random_forest.cc:802] Training of tree  171/300 (tree index:170) done accuracy:0.797239 logloss:0.659021
# [INFO 23-11-24 10:45:25.4356 CST random_forest.cc:802] Training of tree  291/300 (tree index:290) done accuracy:0.805867 logloss:0.611561
# [INFO 23-11-24 10:45:25.4622 CST random_forest.cc:802] Training of tree  231/300 (tree index:230) done accuracy:0.80371 logloss:0.984107
# [INFO 23-11-24 10:45:25.7992 CST random_forest.cc:802] Training of tree  181/300 (tree index:180) done accuracy:0.794075 logloss:0.67142
# [INFO 23-11-24 10:45:25.9759 CST random_forest.cc:802] Training of tree  201/300 (tree index:200) done accuracy:0.795657 logloss:0.656265
# [INFO 23-11-24 10:45:26.2018 CST random_forest.cc:802] Training of tree  181/300 (tree index:180) done accuracy:0.799396 logloss:0.712646
# [INFO 23-11-24 10:45:26.2716 CST random_forest.cc:802] Training of tree  71/300 (tree index:70) done accuracy:0.802128 logloss:1.00501
# [INFO 23-11-24 10:45:26.4376 CST random_forest.cc:802] Training of tree  211/300 (tree index:210) done accuracy:0.802847 logloss:0.61878
# [INFO 23-11-24 10:45:26.6622 CST random_forest.cc:802] Training of tree  300/300 (tree index:299) done accuracy:0.805867 logloss:0.606919
# [INFO 23-11-24 10:45:26.6623 CST random_forest.cc:882] Final OOB metrics: accuracy:0.805867 logloss:0.606919
# [INFO 23-11-24 10:45:26.6955 CST random_forest.cc:416] Training random forest on 6954 example(s) and 11 feature(s).
# [INFO 23-11-24 10:45:26.7256 CST hyperparameters_optimizer.cc:582] [3/50] Score: 0.805867 / 0.805867 HParams: fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_projection_density_factor" value { real: 2 } } fields { name: "sparse_oblique_normalization" value { categorical: "NONE" } } fields { name: "sparse_oblique_weights" value { categorical: "BINARY" } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "winner_take_all" value { categorical: "true" } } fields { name: "max_depth" value { integer: 20 } } fields { name: "min_examples" value { integer: 10 } }
# ...
# [INFO 23-11-24 10:48:33.6496 CST random_forest.cc:802] Training of tree  231/300 (tree index:230) done accuracy:0.802991 logloss:0.891739
# [INFO 23-11-24 10:48:34.4042 CST random_forest.cc:802] Training of tree  91/300 (tree index:90) done accuracy:0.806874 logloss:1.07561
# [INFO 23-11-24 10:48:34.4337 CST random_forest.cc:802] Training of tree  201/300 (tree index:200) done accuracy:0.803135 logloss:0.613962
# [INFO 23-11-24 10:48:34.5347 CST random_forest.cc:802] Training of tree  281/300 (tree index:280) done accuracy:0.808599 logloss:0.693519
# [INFO 23-11-24 10:48:34.6492 CST random_forest.cc:802] Training of tree  300/300 (tree index:299) done accuracy:0.803279 logloss:0.685267
# [INFO 23-11-24 10:48:34.6492 CST random_forest.cc:882] Final OOB metrics: accuracy:0.803279 logloss:0.685267
# [INFO 23-11-24 10:48:34.6664 CST hyperparameters_optimizer.cc:582] [45/50] Score: 0.803279 / 0.808456 HParams: fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_projection_density_factor" value { real: 3 } } fields { name: "sparse_oblique_normalization" value { categorical: "STANDARD_DEVIATION" } } fields { name: "sparse_oblique_weights" value { categorical: "BINARY" } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "winner_take_all" value { categorical: "true" } } fields { name: "max_depth" value { integer: 12 } } fields { name: "min_examples" value { integer: 5 } }
# [INFO 23-11-24 10:48:34.7019 CST random_forest.cc:802] Training of tree  81/300 (tree index:80) done accuracy:0.796951 logloss:0.907508
# [INFO 23-11-24 10:48:34.8529 CST random_forest.cc:802] Training of tree  241/300 (tree index:240) done accuracy:0.804142 logloss:0.883308
# [INFO 23-11-24 10:48:35.9184 CST random_forest.cc:802] Training of tree  101/300 (tree index:100) done accuracy:0.80788 logloss:1.03244
# [INFO 23-11-24 10:48:35.9858 CST random_forest.cc:802] Training of tree  291/300 (tree index:290) done accuracy:0.809031 logloss:0.688694
# [INFO 23-11-24 10:48:36.1051 CST random_forest.cc:802] Training of tree  251/300 (tree index:250) done accuracy:0.802703 logloss:0.883331
# [INFO 23-11-24 10:48:36.1627 CST random_forest.cc:802] Training of tree  91/300 (tree index:90) done accuracy:0.797527 logloss:0.850435
# [INFO 23-11-24 10:48:36.2071 CST random_forest.cc:802] Training of tree  211/300 (tree index:210) done accuracy:0.804142 logloss:0.604659
# [INFO 23-11-24 10:48:37.3038 CST random_forest.cc:802] Training of tree  300/300 (tree index:299) done accuracy:0.808456 logloss:0.684077
# [INFO 23-11-24 10:48:37.3039 CST random_forest.cc:882] Final OOB metrics: accuracy:0.808456 logloss:0.684077
# [INFO 23-11-24 10:48:37.3211 CST hyperparameters_optimizer.cc:582] [46/50] Score: 0.808456 / 0.808456 HParams: fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_projection_density_factor" value { real: 4 } } fields { name: "sparse_oblique_normalization" value { categorical: "MIN_MAX" } } fields { name: "sparse_oblique_weights" value { categorical: "BINARY" } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "winner_take_all" value { categorical: "true" } } fields { name: "max_depth" value { integer: 12 } } fields { name: "min_examples" value { integer: 5 } }
# [INFO 23-11-24 10:48:37.3458 CST random_forest.cc:802] Training of tree  261/300 (tree index:260) done accuracy:0.804142 logloss:0.864659
# [INFO 23-11-24 10:48:37.4256 CST random_forest.cc:802] Training of tree  111/300 (tree index:110) done accuracy:0.808887 logloss:1.01421
# [INFO 23-11-24 10:48:37.6071 CST random_forest.cc:802] Training of tree  101/300 (tree index:100) done accuracy:0.79767 logloss:0.808264
# [INFO 23-11-24 10:48:38.0038 CST random_forest.cc:802] Training of tree  221/300 (tree index:220) done accuracy:0.803135 logloss:0.600187
# [INFO 23-11-24 10:48:38.5770 CST random_forest.cc:802] Training of tree  271/300 (tree index:270) done accuracy:0.80371 logloss:0.864062
# [INFO 23-11-24 10:48:38.9622 CST random_forest.cc:802] Training of tree  121/300 (tree index:120) done accuracy:0.805867 logloss:0.987604
# [INFO 23-11-24 10:48:39.0564 CST random_forest.cc:802] Training of tree  111/300 (tree index:110) done accuracy:0.797383 logloss:0.775148
# [INFO 23-11-24 10:48:39.7990 CST random_forest.cc:802] Training of tree  281/300 (tree index:280) done accuracy:0.80371 logloss:0.860173
# [INFO 23-11-24 10:48:39.8284 CST random_forest.cc:802] Training of tree  231/300 (tree index:230) done accuracy:0.802128 logloss:0.60001
# [INFO 23-11-24 10:48:40.4594 CST random_forest.cc:802] Training of tree  131/300 (tree index:130) done accuracy:0.807018 logloss:0.95585
# [INFO 23-11-24 10:48:40.4970 CST random_forest.cc:802] Training of tree  121/300 (tree index:120) done accuracy:0.796951 logloss:0.751847
# [INFO 23-11-24 10:48:41.0187 CST random_forest.cc:802] Training of tree  291/300 (tree index:290) done accuracy:0.804142 logloss:0.85068
# [INFO 23-11-24 10:48:41.6134 CST random_forest.cc:802] Training of tree  241/300 (tree index:240) done accuracy:0.803998 logloss:0.599845
# [INFO 23-11-24 10:48:41.9237 CST random_forest.cc:802] Training of tree  131/300 (tree index:130) done accuracy:0.797527 logloss:0.732725
# [INFO 23-11-24 10:48:41.9647 CST random_forest.cc:802] Training of tree  141/300 (tree index:140) done accuracy:0.80673 logloss:0.938616
# [INFO 23-11-24 10:48:42.1789 CST random_forest.cc:802] Training of tree  300/300 (tree index:299) done accuracy:0.804142 logloss:0.837187
# [INFO 23-11-24 10:48:42.1790 CST random_forest.cc:882] Final OOB metrics: accuracy:0.804142 logloss:0.837187
# [INFO 23-11-24 10:48:42.1880 CST hyperparameters_optimizer.cc:582] [47/50] Score: 0.804142 / 0.808456 HParams: fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_projection_density_factor" value { real: 3 } } fields { name: "sparse_oblique_normalization" value { categorical: "MIN_MAX" } } fields { name: "sparse_oblique_weights" value { categorical: "CONTINUOUS" } } fields { name: "categorical_algorithm" value { categorical: "RANDOM" } } fields { name: "winner_take_all" value { categorical: "true" } } fields { name: "max_depth" value { integer: 16 } } fields { name: "min_examples" value { integer: 40 } }
# [INFO 23-11-24 10:48:43.3801 CST random_forest.cc:802] Training of tree  141/300 (tree index:140) done accuracy:0.798533 logloss:0.71847
# [INFO 23-11-24 10:48:43.4439 CST random_forest.cc:802] Training of tree  251/300 (tree index:250) done accuracy:0.803279 logloss:0.60028
# [INFO 23-11-24 10:48:43.4542 CST random_forest.cc:802] Training of tree  151/300 (tree index:150) done accuracy:0.805867 logloss:0.909842
# [INFO 23-11-24 10:48:44.8398 CST random_forest.cc:802] Training of tree  151/300 (tree index:150) done accuracy:0.797527 logloss:0.709316
# [INFO 23-11-24 10:48:44.9542 CST random_forest.cc:802] Training of tree  161/300 (tree index:160) done accuracy:0.805292 logloss:0.863242
# [INFO 23-11-24 10:48:45.2510 CST random_forest.cc:802] Training of tree  261/300 (tree index:260) done accuracy:0.803423 logloss:0.581824
# [INFO 23-11-24 10:48:46.3299 CST random_forest.cc:802] Training of tree  161/300 (tree index:160) done accuracy:0.798389 logloss:0.695438
# [INFO 23-11-24 10:48:46.4432 CST random_forest.cc:802] Training of tree  171/300 (tree index:170) done accuracy:0.805004 logloss:0.845106
# [INFO 23-11-24 10:48:47.0523 CST random_forest.cc:802] Training of tree  271/300 (tree index:270) done accuracy:0.80371 logloss:0.576431
# [INFO 23-11-24 10:48:47.8158 CST random_forest.cc:802] Training of tree  171/300 (tree index:170) done accuracy:0.799396 logloss:0.658097
# [INFO 23-11-24 10:48:47.9233 CST random_forest.cc:802] Training of tree  181/300 (tree index:180) done accuracy:0.806299 logloss:0.836863
# [INFO 23-11-24 10:48:48.8344 CST random_forest.cc:802] Training of tree  281/300 (tree index:280) done accuracy:0.803998 logloss:0.576163
# [INFO 23-11-24 10:48:49.3089 CST random_forest.cc:802] Training of tree  181/300 (tree index:180) done accuracy:0.800115 logloss:0.657434
# [INFO 23-11-24 10:48:49.4412 CST random_forest.cc:802] Training of tree  191/300 (tree index:190) done accuracy:0.804142 logloss:0.818559
# [INFO 23-11-24 10:48:50.6514 CST random_forest.cc:802] Training of tree  291/300 (tree index:290) done accuracy:0.803566 logloss:0.576203
# [INFO 23-11-24 10:48:50.7709 CST random_forest.cc:802] Training of tree  191/300 (tree index:190) done accuracy:0.800546 logloss:0.634108
# [INFO 23-11-24 10:48:50.9336 CST random_forest.cc:802] Training of tree  201/300 (tree index:200) done accuracy:0.804142 logloss:0.804965
# [INFO 23-11-24 10:48:52.2589 CST random_forest.cc:802] Training of tree  201/300 (tree index:200) done accuracy:0.799396 logloss:0.63372
# [INFO 23-11-24 10:48:52.2849 CST random_forest.cc:802] Training of tree  300/300 (tree index:299) done accuracy:0.803998 logloss:0.571224
# [INFO 23-11-24 10:48:52.2850 CST random_forest.cc:882] Final OOB metrics: accuracy:0.803998 logloss:0.571224
# [INFO 23-11-24 10:48:52.3168 CST hyperparameters_optimizer.cc:582] [48/50] Score: 0.803998 / 0.808456 HParams: fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_projection_density_factor" value { real: 5 } } fields { name: "sparse_oblique_normalization" value { categorical: "MIN_MAX" } } fields { name: "sparse_oblique_weights" value { categorical: "BINARY" } } fields { name: "categorical_algorithm" value { categorical: "CART" } } fields { name: "winner_take_all" value { categorical: "true" } } fields { name: "max_depth" value { integer: 25 } } fields { name: "min_examples" value { integer: 10 } }
# [INFO 23-11-24 10:48:52.4268 CST random_forest.cc:802] Training of tree  211/300 (tree index:210) done accuracy:0.805436 logloss:0.786052
# [INFO 23-11-24 10:48:53.7135 CST random_forest.cc:802] Training of tree  211/300 (tree index:210) done accuracy:0.801553 logloss:0.633455
# [INFO 23-11-24 10:48:53.9123 CST random_forest.cc:802] Training of tree  221/300 (tree index:220) done accuracy:0.805436 logloss:0.776922
# [INFO 23-11-24 10:48:55.1839 CST random_forest.cc:802] Training of tree  221/300 (tree index:220) done accuracy:0.800546 logloss:0.633172
# [INFO 23-11-24 10:48:55.3687 CST random_forest.cc:802] Training of tree  231/300 (tree index:230) done accuracy:0.806299 logloss:0.767963
# [INFO 23-11-24 10:48:56.6324 CST random_forest.cc:802] Training of tree  231/300 (tree index:230) done accuracy:0.801697 logloss:0.633358
# [INFO 23-11-24 10:48:56.8306 CST random_forest.cc:802] Training of tree  241/300 (tree index:240) done accuracy:0.806586 logloss:0.749436
# [INFO 23-11-24 10:48:58.0644 CST random_forest.cc:802] Training of tree  241/300 (tree index:240) done accuracy:0.802128 logloss:0.633165
# [INFO 23-11-24 10:48:58.2949 CST random_forest.cc:802] Training of tree  251/300 (tree index:250) done accuracy:0.805723 logloss:0.744582
# [INFO 23-11-24 10:48:59.5101 CST random_forest.cc:802] Training of tree  251/300 (tree index:250) done accuracy:0.801409 logloss:0.632455
# [INFO 23-11-24 10:48:59.7428 CST random_forest.cc:802] Training of tree  261/300 (tree index:260) done accuracy:0.805148 logloss:0.735408
# [INFO 23-11-24 10:49:00.9426 CST random_forest.cc:802] Training of tree  261/300 (tree index:260) done accuracy:0.802272 logloss:0.623299
# [INFO 23-11-24 10:49:01.2078 CST random_forest.cc:802] Training of tree  271/300 (tree index:270) done accuracy:0.80558 logloss:0.7306
# [INFO 23-11-24 10:49:02.3609 CST random_forest.cc:802] Training of tree  271/300 (tree index:270) done accuracy:0.801984 logloss:0.618643
# [INFO 23-11-24 10:49:02.6723 CST random_forest.cc:802] Training of tree  281/300 (tree index:280) done accuracy:0.804861 logloss:0.730489
# [INFO 23-11-24 10:49:03.7935 CST random_forest.cc:802] Training of tree  281/300 (tree index:280) done accuracy:0.801409 logloss:0.614137
# [INFO 23-11-24 10:49:04.1578 CST random_forest.cc:802] Training of tree  291/300 (tree index:290) done accuracy:0.805867 logloss:0.730646
# [INFO 23-11-24 10:49:05.2289 CST random_forest.cc:802] Training of tree  291/300 (tree index:290) done accuracy:0.801697 logloss:0.609507
# [INFO 23-11-24 10:49:05.4929 CST random_forest.cc:802] Training of tree  300/300 (tree index:299) done accuracy:0.806155 logloss:0.72171
# [INFO 23-11-24 10:49:05.4930 CST random_forest.cc:882] Final OOB metrics: accuracy:0.806155 logloss:0.72171
# [INFO 23-11-24 10:49:05.5062 CST hyperparameters_optimizer.cc:582] [49/50] Score: 0.806155 / 0.808456 HParams: fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_projection_density_factor" value { real: 5 } } fields { name: "sparse_oblique_normalization" value { categorical: "NONE" } } fields { name: "sparse_oblique_weights" value { categorical: "BINARY" } } fields { name: "categorical_algorithm" value { categorical: "RANDOM" } } fields { name: "winner_take_all" value { categorical: "true" } } fields { name: "max_depth" value { integer: 12 } } fields { name: "min_examples" value { integer: 10 } }
# [INFO 23-11-24 10:49:06.5219 CST random_forest.cc:802] Training of tree  300/300 (tree index:299) done accuracy:0.802272 logloss:0.609216
# [INFO 23-11-24 10:49:06.5220 CST random_forest.cc:882] Final OOB metrics: accuracy:0.802272 logloss:0.609216
# [INFO 23-11-24 10:49:06.5530 CST hyperparameters_optimizer.cc:582] [50/50] Score: 0.802272 / 0.808456 HParams: fields { name: "split_axis" value { categorical: "SPARSE_OBLIQUE" } } fields { name: "sparse_oblique_projection_density_factor" value { real: 3 } } fields { name: "sparse_oblique_normalization" value { categorical: "STANDARD_DEVIATION" } } fields { name: "sparse_oblique_weights" value { categorical: "BINARY" } } fields { name: "categorical_algorithm" value { categorical: "RANDOM" } } fields { name: "winner_take_all" value { categorical: "true" } } fields { name: "max_depth" value { integer: 25 } } fields { name: "min_examples" value { integer: 10 } }
# [INFO 23-11-24 10:49:06.6578 CST hyperparameters_optimizer.cc:219] Best hyperparameters:
# fields {
#   name: "split_axis"
#   value {
#     categorical: "SPARSE_OBLIQUE"
#   }
# }
# fields {
#   name: "sparse_oblique_projection_density_factor"
#   value {
#     real: 2
#   }
# }
# fields {
#   name: "sparse_oblique_normalization"
#   value {
#     categorical: "NONE"
#   }
# }
# fields {
#   name: "sparse_oblique_weights"
#   value {
#     categorical: "CONTINUOUS"
#   }
# }
# fields {
#   name: "categorical_algorithm"
#   value {
#     categorical: "CART"
#   }
# }
# fields {
#   name: "winner_take_all"
#   value {
#     categorical: "true"
#   }
# }
# fields {
#   name: "max_depth"
#   value {
#     integer: 12
#   }
# }
# fields {
#   name: "min_examples"
#   value {
#     integer: 2
#   }
# }
#
# [INFO 23-11-24 10:49:06.6583 CST kernel.cc:919] Export model in log directory: /var/folders/2j/5hwf_xns24z3hc6bmf268x340000gn/T/tmporblgvqk with prefix eb4621bc32b34f96
# [INFO 23-11-24 10:49:06.7331 CST kernel.cc:937] Save model in resources
# [INFO 23-11-24 10:49:06.7344 CST abstract_model.cc:881] Model self evaluation:
# Number of predictions (without weights): 6954
# Number of predictions (with weights): 6954
# Task: CLASSIFICATION
# Label: __LABEL
#
# Accuracy: 0.808456  CI95[W][0.800526 0.816193]
# LogLoss: : 0.748133
# ErrorRate: : 0.191544
#
# Default Accuracy: : 0.503307
# Default LogLoss: : 0.693125
# Default ErrorRate: : 0.496693
#
# Confusion Table:
# truth\prediction
#       1     2
# 1  2765   689
# 2   643  2857
# Total: 6954
#
#
# [INFO 23-11-24 10:49:06.8443 CST kernel.cc:1233] Loading model from path /var/folders/2j/5hwf_xns24z3hc6bmf268x340000gn/T/tmporblgvqk/model/ with prefix eb4621bc32b34f96
# [INFO 23-11-24 10:49:07.0600 CST decision_forest.cc:660] Model loaded with 300 root(s), 142808 node(s), and 11 input feature(s).
# [INFO 23-11-24 10:49:07.0600 CST abstract_model.cc:1344] Engine "RandomForestGeneric" built
# [INFO 23-11-24 10:49:07.0600 CST kernel.cc:1061] Use fast generic engine
# Model trained in 0:04:20.965194
# Compiling model...
# Model compiled.

# %%
model = tfdf.keras.RandomForestModel(
    split_axis="SPARSE_OBLIQUE",
    sparse_oblique_projection_density_factor=2.0,
    sparse_oblique_weights="CONTINUOUS",
    max_depth=12,
    min_examples=2,
)
model.fit(train_ds)
# Out:
# Use /var/folders/2j/5hwf_xns24z3hc6bmf268x340000gn/T/tmppraqn49l as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:00.126559. Found 6954 examples.
# Training model...
# [INFO 23-11-24 10:57:58.8168 CST kernel.cc:1233] Loading model from path /var/folders/2j/5hwf_xns24z3hc6bmf268x340000gn/T/tmppraqn49l/model/ with prefix ab04fa1e16994515
# Model trained in 0:00:04.037549
# Compiling model...
# Model compiled.
# [INFO 23-11-24 10:57:59.0286 CST decision_forest.cc:660] Model loaded with 300 root(s), 142808 node(s), and 11 input feature(s).
# [INFO 23-11-24 10:57:59.0286 CST abstract_model.cc:1344] Engine "RandomForestGeneric" built
# [INFO 23-11-24 10:57:59.0286 CST kernel.cc:1061] Use fast generic engine

# %%
valid_preds = model.predict(valid_ds)
# Out:
# 2/2 [==============================] - 0s 39ms/step

# %%
from sklearn.metrics import accuracy_score


def best_threshold(y_test_value, y_pred_probability):
    best_score = 0
    best_threshold = 0

    for threshold in np.arange(0.2, 0.81, 0.01):
        predictions = (y_pred_probability > threshold).astype(int)
        m = accuracy_score(y_test_value, predictions)
        if m > best_score:
            best_score = m
            best_threshold = threshold

    return best_threshold


best_threshold(val_df.Transported, valid_preds)
# Out:
# 0.49000000000000027

# %%
test_df = pd.read_csv("data/test.csv")
submission_id = test_df.PassengerId
for c in ("VIP", "CryoSleep", "FoodCourt", "ShoppingMall", "Spa", "VRDeck"):
    test_df[c].fillna(value=0, inplace=True)
test_df["Cabin"] = test_df["Cabin"].apply(
    lambda x: x[0] + x[-1] if pd.notnull(x) and x != "" else x
)
test_df["VIP"] = test_df["VIP"].astype(int)
test_df["CryoSleep"] = test_df["CryoSleep"].astype(int)

# %%
test_ds = tfdf.keras.pd_dataframe_to_tf_dataset(test_df)
predictions = model.predict(test_ds)
# Out:
# 5/5 [==============================] - 0s 43ms/step

# %%
n_predictions = (predictions > 0.48).astype(bool)
sample_submission_df = pd.read_csv("data/sample_submission.csv")
sample_submission_df["Transported"] = n_predictions
sample_submission_df.to_csv("my_submission.csv", index=False)
